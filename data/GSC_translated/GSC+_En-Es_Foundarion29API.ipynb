# %%
# !pip3 install googletrans
# Out:
# Processing c:\users\nichibuy\appdata\local\pip\cache\wheels\20\da\eb\a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d\googletrans-3.0.0-py3-none-any.whl
# Collecting httpx==0.13.3
#   Using cached httpx-0.13.3-py3-none-any.whl (55 kB)
# Collecting sniffio
#   Using cached sniffio-1.1.0-py3-none-any.whl (4.5 kB)
# Collecting hstspreload
#   Using cached hstspreload-2020.7.29-py3-none-any.whl (926 kB)
# Requirement already satisfied: certifi in c:\users\nichibuy\appdata\local\continuum\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2019.9.11)
# Collecting rfc3986<2,>=1.3
#   Using cached rfc3986-1.4.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: idna==2.* in c:\users\nichibuy\appdata\local\continuum\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (2.8)
# Collecting httpcore==0.9.*
#   Using cached httpcore-0.9.1-py3-none-any.whl (42 kB)
# Requirement already satisfied: chardet==3.* in c:\users\nichibuy\appdata\local\continuum\anaconda3\lib\site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Collecting h11<0.10,>=0.8
#   Using cached h11-0.9.0-py2.py3-none-any.whl (53 kB)
# Collecting h2==3.*
#   Using cached h2-3.2.0-py2.py3-none-any.whl (65 kB)
# Collecting hyperframe<6,>=5.2.0
#   Using cached hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Using cached hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Installing collected packages: sniffio, hstspreload, rfc3986, h11, hyperframe, hpack, h2, httpcore, httpx, googletrans
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2020.7.29 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.4.0 sniffio-1.1.0
# WARNING: You are using pip version 20.0.2; however, version 20.2 is available.
# You should consider upgrading via the 'c:\users\nichibuy\appdata\local\continuum\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import requests
import time
import googletrans
from googletrans import Translator

# %%
gsc_data = pd.read_csv('GSC+.csv', converters={'HPO_codes': eval, 'starts': eval, 'ends': eval, 'HPO_symptoms': eval})

# %%
def call_f29_translate_api(doc_id,text,endpoint,headers,params):
    
     #Translate the description of the condition symptom(s), default source language is English (en)
    data = '{"language_source":"en","segments":[{"id":"'+ str(doc_id)+ '","source":"'+ text +'"}]}'
    return requests.post(endpoint, headers=headers, params=params, data=data)

# %%
def translate_english_spanish(doc_id,text, symptoms, hpo_codes):
    
    #define HTTP header, param and endpoint
    endpoint = 'https://f29bio-dev.northeurope.cloudapp.azure.com/api/Translation/document/translate-hack'
    headers = {'accept': 'text/plain','Content-Type': 'application/json',}
    params = (('lan', 'es'),) #Set target languages, default here is Spanish (es)
    
    #Translate the description of the condition (symptom(s))
    response = call_f29_translate_api(doc_id,text,endpoint,headers,params)
    
    if response.status_code == 200:
        
        output = response.json()
        file = output['segments'][0]['id']
        spanish_translation = output['segments'][0]['target']
        translated_symptoms = []
        
        #translate the symtoms themselves
        for symptom in symptoms:
            response = call_f29_translate_api(doc_id,symptom,endpoint,headers,params)
            if response.status_code == 200:
                output = response.json()
                translated_symptoms.append(output['segments'][0]['target'])
            else:
                return{}
            
        #Return all the data to mimic original file although, but also keep origianl english text         
        return {
            'Archivo': file,
            'Texto_espanol': spanish_translation,
            'Texto_inglés': text,
            'HPO_síntomas': translated_symptoms,
            'HPO_código': hpo_codes
        }
    else:
        return{}

# %%
#Translate all rows and create a dataframe

translation_rows = []
for row in gsc_data.itertuples():
    translation_output = translate_english_spanish(row[1], row[2], row[3], row[4])
    translation_rows.append(translation_output)
    if (row[0] + 1) % 10 == 0:
        print('Fetched {} rows'.format(row[0] + 1))
        time.sleep(1)
translation_df = pd.DataFrame(translation_rows)

# %%
#Drop all Nan values
translation_df.dropna()
# Out:
#       Archivo                                      Texto_espanol  \
# 0     1003450  En cinco miembros de una familia italiana se r...
# 1    10051003  El síndrome de Townes-Brock (TBS) es un trasto...
# 2    10066029  El síndrome de carcinoma basocelular nevoide (...
# 3    10196695  El síndrome de Angélica (EA) es un trastorno d...
# 4    10417280  El síndrome de Prader-Willi (PWS) y el síndrom...
# ..        ...                                                ...
# 223   9831341  Hemos descrito previamente a un paciente con u...
# 224   9863591  Los pacientes que presentan schwanomas vestibu...
# 225   9931336  Se han identificado mutaciones del gen parchea...
# 226   9949213  Los elementos de repetición de copia baja se a...
# 227    998578  Una mujer con síndrome autosómica dominante de...
#
#                                           Texto_inglés  \
# 0    A syndrome of brachydactyly (absence of some m...
# 1    Townes-Brocks syndrome (TBS) is an autosomal d...
# 2    Nevoid basal cell carcinoma syndrome (NBCCS) i...
# 3    Angelman syndrome (AS) is a neurodevelopmental...
# 4    Prader-Willi syndrome (PWS) and Angelman syndr...
# ..                                                 ...
# 223  We had previously described a patient with an ...
# 224  Patients who present with unilateral vestibula...
# 225  Mutations of the human Patched gene ( PTCH ) h...
# 226  Transcribed, low-copy repeat elements are asso...
# 227  A woman with the autosomal dominant syndrome o...
#
#                                           HPO_síntomas  \
# 0    [brachydactyly, ausencia de algunas falanges m...
# 1    [trastorno autosómico dominante., autosómica d...
# 2    [carcinoma basocelular., autosómica dominante....
# 3    [trastorno del neurodesarrollo, síndrome del g...
# 4              [trastornos neuroconductuales, de Novo]
# ..                                                 ...
# 223   [crecimiento, hiperfagia, obesidad, crecimiento]
# 224  [schwanomas vestibulares unilaterales., schwan...
# 225  [carcinoma basocelular., esporádicos, carcinom...
# 226     [anomalías del desarrollo, letalidad juvenil.]
# 227  [autosómica dominante., dominante, fosas preau...
#
#                                             HPO_código
# 0    [0001156, 0009881, 0001798, 0001792, 0100264, ...
# 1    [0000006, 0000006, 0000006, 0003828, 0003813, ...
# 2    [0002671, 0000006, 0000006, 0000006, 0000006, ...
# 3                                   [0000707, 0001466]
# 4                                   [0000708, 0003745]
# ..                                                 ...
# 223               [0001548, 0002591, 0001513, 0001548]
# 224  [0009590, 0009588, 0100008, 0003593, 0003593, ...
# 225  [0002671, 0003745, 0002671, 0002885, 0002671, ...
# 226                                 [0001263, 0004149]
# 227  [0000006, 0000006, 0004467, 0004467, 0009795, ...
#
# [202 rows x 5 columns]

# %%
#Save to file
translation_df.to_csv('GSC+_es_and_en.csv')

# %% [markdown]
# ## Using GoogleTranslate

# %%
gsc_data = pd.read_csv('gsc.csv', converters={'Archivo': eval, 'Texto_espanol': eval, 'Texto_inglés': eval, 'HPO_síntomas': eval,'HPO_código':eval })
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\NICHIBUY\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-a09e6b4b2015>", line 1, in <module>
#     gsc_data = pd.read_csv('gsc.csv', converters={'Archivo': eval, 'Texto_espanol': eval, 'Texto_inglés': eval, 'HPO_síntomas': eval,'HPO_código':eval })
#
#   File "C:\Users\NICHIBUY\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py", line 685, in parser_f
#     return _read(filepath_or_buffer, kwds)
#
#   File "C:\Users\NICHIBUY\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py", line 463, in _read
#     data = parser.read(nrows)
#
#   File "C:\Users\NICHIBUY\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py", line 1154, in read
#     ret = self._engine.read(nrows)
#
#   File "C:\Users\NICHIBUY\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py", line 2059, in read
#     data = self._reader.read(nrows)
#
#   File "pandas\_libs\parsers.pyx", line 881, in pandas._libs.parsers.TextReader.read
#
#   File "pandas\_libs\parsers.pyx", line 896, in pandas._libs.parsers.TextReader._read_low_memory
#
#   File "pandas\_libs\parsers.pyx", line 973, in pandas._libs.parsers.TextReader._read_rows
#
#   File "pandas\_libs\parsers.pyx", line 1083, in pandas._libs.parsers.TextReader._convert_column_data
#
#   File "pandas\_libs\parsers.pyx", line 2231, in pandas._libs.parsers._apply_converter
#
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing
